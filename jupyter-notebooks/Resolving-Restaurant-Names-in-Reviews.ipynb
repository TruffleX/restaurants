# %% [markdown]
# ### Solution 1: Straight Match
#
# Build a phrase matcher in Spacy; count occurances over the title, description, and article, pick the most common.
#
# ### Issues:
#
# - Doesnt handle multiple valid mentions within a doc
# - Doesnt match single name restaurants.

# %%
from collections import Counter
from tqdm import tqdm_notebook
import time
from spacy.matcher import PhraseMatcher
import spacy

from db.dbclient import MongoClient

def read_gazetteer(tokenizer, restaurant_iter):
    
    names = map(lambda x: x.get('name'), restaurant_iter)    
    for i, name in enumerate(names):
        phrase = tokenizer(name)
        for w in phrase:
            _ = tokenizer.vocab[w.text]
        if len(phrase) >= 2 and len(phrase) < 10:
            yield phrase
            
def get_matches(tokenizer, phrases, texts, max_length=10):
    matcher = PhraseMatcher(tokenizer.vocab, max_length=max_length)
    matcher.add('Phrase', None, *phrases)
    for text in texts:
        doc = tokenizer(text)
        for w in doc:
            _ = doc.vocab[w.text]
        matches = matcher(doc)
        for ent_id, start, end in matches:
            yield (ent_id, doc[start:end].text)  
            
def get_phrases():
    restaurant_iter = MongoClient('restaurant').collection.find({})
    nlp = spacy.blank('en')
    nlp.vocab.lex_attr_getters = {}
    phrases = read_gazetteer(nlp.tokenizer, restaurant_iter)
    return phrases
            
def main():
    restaurant_iter = MongoClient('restaurant').collection.find({})
    article_iter = MongoClient('articles').collection.find({'is_review_score': {"$gt":.5}})
    nlp = spacy.blank('en')
    nlp.vocab.lex_attr_getters = {}
    phrases = read_gazetteer(nlp.tokenizer, restaurant_iter)
    matcher = PhraseMatcher(nlp.tokenizer.vocab, max_length=10)
    matcher.add('Phrase', None, *phrases)
    results = {}
    for article in tqdm_notebook(article_iter):
        texts = [article.get('content', " "), article.get('title', " "), article.get('meta_description', " ")]
        results[article['_id']] = {'text': texts, 'matches': Counter(), 'is_review_score': article['is_review_score']}
        for text in texts:
            doc = nlp.tokenizer(text)
            for w in doc:
                _ = doc.vocab[w.text]
            matches = matcher(doc)
            for ent_id, start, end in matches:
                results[article['_id']]['matches'][doc[start:end].text] += 1
        most_common = results[article['_id']]['matches'].most_common(1)
        if most_common:
            pick, count = most_common[0]
            if count > 1:
                results[article['_id']]['best_match'] = pick
            else:
                results[article['_id']]['best_match'] = None
        else:
            results[article['_id']]['best_match'] = None
    return results

# %%
# !rm -r titles

# %%
# !mkdir titles
for i, title in enumerate(df['title'].values.tolist()):
    with open(f'titles/title_{i}.txt', 'w') as f:
        f.write(title)

# %%
ls titles
# Out:
# title_0.txt    title_13.txt   title_17.txt   title_24.txt  title_64.txt
# title_100.txt  title_140.txt  title_180.txt  title_25.txt  title_65.txt
# title_101.txt  title_141.txt  title_181.txt  title_26.txt  title_66.txt
# title_102.txt  title_142.txt  title_182.txt  title_27.txt  title_67.txt
# title_103.txt  title_143.txt  title_183.txt  title_28.txt  title_68.txt
# title_104.txt  title_144.txt  title_184.txt  title_29.txt  title_69.txt
# title_105.txt  title_145.txt  title_185.txt  title_2.txt   title_6.txt
# title_106.txt  title_146.txt  title_186.txt  title_30.txt  title_70.txt
# title_107.txt  title_147.txt  title_187.txt  title_31.txt  title_71.txt
# 91,Glena’s Tacos & Margaritas - Dogpatch - San Francisco - The Infatuation
# 92,Where To Have Dinner For Around $30 In Silver Lake - Silver Lake - Los Angeles - The Infatuation
# 93,A Guide To SF’s “Super Cute Reasonably Priced Restaurants To Catch Up With A Few Friends” - San Francisco - The Infatuation
# 94,The NYC Hit List: The Best New Restaurants In NYC - New York - The Infatuation
# 95,Di An Di - Greenpoint - New York - The Infatuation
# 96,Best Restaurants in UK: Top 100 Outside London
# 97,The LA Hit List: The Best New Restaurants In Los Angeles - Los Angeles - The Infatuation
# 98,The Ride-Along Report:  First Takes From Last Night’s Dinner - Los Angeles - The Infatuation
# 99,APL - Hollywood - Los Angeles - The Infatuation
# 100,Doubting Thomas - Historic Filipinotown - Los Angeles - The Infatuation
# 101,Pearl’s BBQ - Los Angeles - The Infatuation
# 102,Rick’s - Downtown LA - Los Angeles - The Infatuation
# 103,Little Prince - Santa Monica - Los Angeles - The Infatuation
# 104,"Chicago’s New Restaurant Openings
#  - Chicago - The Infatuation"
# 105,22 Best Restaurants in Amsterdam - Condé Nast Traveler
# 106,Davenport’s in Encino offers a unique dining experience — once you find it – Daily News
# 107,Enjoy Some of The Top Restaurants in Philadelphia
# 108,The Town Baker - Idyllwild - Los Angeles - The Infatuation
# 109,Cafe Aroma - Idyllwild - Los Angeles - The Infatuation
# 110,Idyll Awhile Wine Shop - Idyllwild - Los Angeles - The Infatuation
# 111,Idyllwild Bake Shop & Brew - Idyllwild - Los Angeles - The Infatuation
# 112,Idyllwild Brewpub - Idyllwild - Los Angeles - The Infatuation
# 113,Higher Grounds - Idyllwild - Los Angeles - The Infatuation
# 114,Tommy’s Kitchen - Idyllwild - Los Angeles - The Infatuation
# 115,Ferro - Idyllwild - Los Angeles - The Infatuation
# 116,Pie For The People - Joshua Tree - Los Angeles - The Infatuation
# 117,Joshua Tree Coffee - Joshua Tree - Los Angeles - The Infatuation
# 118,Jonathan Gold keeps returning to Chong Qing Special Noodles for hard-rocking heat
# 119,Jonathan Gold finds magical nostalgia at Freedman's in Silver Lake
# 120,Fainting Goat Gelato - Wallingford - Seattle - The Infatuation
# 121,The Tropicale - Palm Springs - Los Angeles - The Infatuation
# 122,Birba - Palm Springs - Los Angeles - The Infatuation
# 123,Melvyn’s - Palm Springs - Los Angeles - The Infatuation
# 124,Felipe’s - Palm Springs - Los Angeles - The Infatuation
# 125,So.pa - Palm Springs - Los Angeles - The Infatuation
# 126,Truss & Twine - Palm Springs - Los Angeles - The Infatuation
# 127,4 Saints - Palm Springs - Los Angeles - The Infatuation
# 128,Rooster And The Pig - Palm Springs - Los Angeles - The Infatuation
# 129,Little Water Cantina - Eastlake - Seattle - The Infatuation
# 130,Street Treats - Central District - Seattle - The Infatuation
# 131,Full Tilt Ice Cream - Capitol Hill - Seattle - The Infatuation
# 132,D’Ambrosio Gelato - Ballard - Seattle - The Infatuation
# 133,Cupcake Royale and Vérité Coffee - Capitol Hill - Seattle - The Infatuation
# 134,Gelatiamo - Downtown - Seattle - The Infatuation
# 181,Bavel - Los Angeles - The Infatuation
# 182,Buddha Bruddah - Beacon Hill - Seattle - The Infatuation
# 183,Tapas Lab - Green Lake - Seattle - The Infatuation
# 184,Pho Viet Anh - Queen Anne - Seattle - The Infatuation
# 185,This world-famous chef is opening a coffee shop and soul food restaurant in West Adams
# 186,Sotto Sotto - Inman Park - Atlanta - The Infatuation
# 187,Minero - Old Fourth Ward - Atlanta - The Infatuation
# 188,Bocado - West Midtown - Atlanta - The Infatuation
# 189,JCT Kitchen & Bar - West Midtown - Atlanta - The Infatuation
# 190,Beetlecat - Inman Park - Atlanta - The Infatuation
# 191,Le Fat - West Midtown - Atlanta - The Infatuation
# 192,Kimball House - Decatur - Atlanta - The Infatuation
# 193,Gunshow - Glenwood Park - Atlanta - The Infatuation
# 194,Miller Union - West Midtown - Atlanta - The Infatuation
# 195,Knott’s Berry Farm new menu items include a mango Icee with Chamoy and Tajin – Daily News
# 196,"French food at Montresor in Studio City is not fancy, but it sure is good – Daily News"
# 197,Jonathan Gold turns up the heat at Chongqing Special Noodles
# 198,Where To Have Dinner For Around $30 In Santa Monica - Santa Monica - Los Angeles - The Infatuation
# 199,The Guide To Affordable Eating in Beverly Hills - Beverly Hills - Los Angeles - The Infatuation
# 200,The Honorable William Wall - New Jersey - New York - The Infatuation
# 201,The Staten Island Ferry - New York - The Infatuation
# 202,Hudson’s - New York - The Infatuation
# 203,The Frying Pan - Chelsea - New York - The Infatuation
# 204,Great SF Restaurants For Dining Solo - San Francisco - The Infatuation
# 205,Celestine - DUMBO - New York - The Infatuation
# 206,All Time - Los Feliz - Los Angeles - The Infatuation
# 207,Otis - East Williamsburg - New York - The Infatuation
# 208,Ophelia - New York - The Infatuation
# 209,Madre Mezcaleria - Prospect Heights - New York - The Infatuation
# 210,Tacombi Fort Greene - Fort Greene - New York - The Infatuation
# 211,The Ride-Along Report: First Takes From Last Night’s Dinner - New York - The Infatuation
# 212,Fada - Williamsburg - New York - The Infatuation
# 213,Joe’s Falafel - Studio City - Los Angeles - The Infatuation
# 214,Henry’s Tacos - Studio City - Los Angeles - The Infatuation
# 215,Lal Mirch - Studio City - Los Angeles - The Infatuation

# %%
cl = MongoClient('articles').collection
reviews = cl.find({"is_review_score": {"$gt": .5}})
#titles = [i['title'] for i in reviews]

# %%
import pandas as pd
df = pd.DataFrame(list(reviews))

# %%
df['title'].to_csv("reviews.csv", index=False, index_label=None)

# %%
df['title'].to_csv("review_titles.csv")

# %%
next(sents)
# Out:
# “

# %%
next(sents)
# Out:
# It’s great to have (people) finally here drinking, sitting down and drinking beer,” he said on the opening day of Liberation Brewing Company, the city’s latest brewery that Regan launched with his high school friend Michael Clements and brewer Eric McLaughlin.

# %%
next(sents)
# Out:
# The Liberation Brewing Company opened its Long beach location this week on May 3 at 3630 Atlantic Avenue.

# %%
next(sents)
# Out:
# (Photo by Hans Gutknecht, Los Angeles Daily News/SCNG)

# %%
next(sents)
# Out:
# The “Saved by the Bell”-themed pop-up

# %% [markdown]
# ### Signals of referencing a restaurant
#
# * Capital Letters
# * preceeded by at/in
# * preceeded by restaurant/diner/project etc -> learn corpus specific word embdeddings
# * Ends with cafe/diner/restaurant
#
# ### Signals of a target of a review
# * Lots of mentions of the restaurant.

# %%
"""
The models.py module contains abstractions for grabbing information from db
to present within a view.

A view consumes a list of dictionaries; each of which either contains:

* lat/lon coordinates
* title
* text/images for each info window (styling will be handled elsewhere)

To avoid relying on places API whenever we want to get the location of a restaurant, lat/lon
should be stored in db.

We have have to this type of annotation as an ETL process.

See documentation for details on data models.
"""


from db.dbclient import MongoClient

class Restaurants:
    def __init__(self, dao):
        self.dao = dao.db.get_collection('restaurant')

    def filter_by_coords(self, west=None, east=None, north=None, south=None):
        if any([i is None for i in [west, east, south, north]]):
            raise ValueError("Must pass in values for all coordinates")

        query = {
            'coords.lat': {'$lt': east, '$gt': west},
            'coords.lon': {'$gt': south, '$lt': north},
        }

        return self.dao.find(query)

    def get_all(self):
        return filter(self.is_5_star, filter(self.is_valid, self.dao.find({})))

    def is_valid(self, blob):
        coords = blob.get('coords')
        if coords is None:
            return False
        lat, lon = coords.get('lat'), coords.get('lon')
        if lat is None or lon is None:
            return False
        if not isinstance(lat, float) or not isinstance(lon, float):
            return False
        return True

    def is_5_star(self, review):
        yelp = review.get('yelp')
        if yelp is None:
            return False
        rating = yelp.get('rating')
        if rating is None:
            return False
        if rating < 4:
            return False
        return True

class Model:
    def __init__(self):
        self.DataAccessObject = MongoClient()
        self.restaurants = Restaurants(self.DataAccessObject)
db_model = Model()

# %%
results = main()
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
#ids = (i for i in results.keys())
results[next(ids)]
# Out:
# {'best_match': 'Food',
#  'is_review_score': 0.9990043640136719,
#  'matches': Counter({'3': 4,
#           'America': 1,
#           'California': 1,
#           'Food': 4,
#           'Mori': 1,
#           'San': 1,
#           'Shiki Beverly Hills': 1}),
#  'text': ["\nDONATE\n \nAll Things Considered\nNational Public Radio's weekday afternoon newsmagazine.\n \nEclectic 24\nKCRW's all-music channel Eclectic24, blending the collected talents and tastes of KCRW's DJs into a single voice. Free music streaming 24/7 at KCRW.com.\n \nAll Things Considered\nNational Public Radio's weekday afternoon newsmagazine.\n \nLost Notes\nThe greatest music stories never told. Explore the amazing stories of how 60s rock hit “Louie, Louie” triggered an FBI investigation, the outlaw Brooklyn radio station WBAD that tracked the rise of 90s hip hop, and the man who went from Folsom Prison inmate to Johnny Cash’s bandmate.\n \nUnFictional\nUnbelievably true stories of chance encounters that changed the world. A pair of mail-order shoes that led to the film The Outsiders. A secret road to a California paradise. The day LA and smog first met. Stories that will stick in your head like a memory. It’s UnFictional, hosted by Bob Carlson.\n \nTo the Point\nA weekly reality-check on the issues Americans care about most. Host Warren Olney draws on his decades of experience to explore the people and issues shaping – and disrupting - our world. How did everything change so fast? Where are we headed? The conversations are informal, edgy and always informative. If Warren's asking, you want to know the answer.\n \nDONATE!\n Jonathan Gold heads to Michael Voltaggio’s Ink.well to find a slightly more accessible reboot of his shuttered restaurant Ink. \nLISTEN TO THIS EPISODE\n Nov 17, 2017 Some eaters find themselves divided on chef Michael Voltaggio’s cooking. Jonathan Gold says his newest restaurant Ink.well might be regarded as a slightly more user friendly version of its previous incarnation, Ink. With a date-ready ambience and eclectic menu, this spot is a showcase for Voltaggio’s ambitious cooking, informed by his haute cuisine resume. Ink.well chef Michael Voltaggio. (Photo by The Hundreds) Ink.well: 826 N La Cienega Blvd, Los Angeles, CA 90069 | 310.358.9058 \n                Hosts:Jonathan GoldEvan Kleiman \n                Producers:Nick LiaoRosalie Atkinson \n\n\n        Jonathan Gold recounts the LA Times Food Bowl's Sichuan Summit\n      \n\n\n\n        The LA Times Food Bowl runs through the month of May. Jonathan Gold reports on how it’s been going so far..\n      \n\n \n3 MIN, 56 SEC\nMay 11, 2018\n \n\n\n        Jonathan Gold eats clay pot rice at Nature Pagoda in San Gabriel\n      \n\n\n\n        Jonathan Gold praises the beautiful crusty rice at the bottom of Nature Pagoda’s sizzling clay pots.\n      \n\n \n3 MIN, 58 SEC\nApr 27, 2018\n \n\n\n        Jonathan Gold steps into David Chang's orbit at Majordomo\n      \n\n\n\n        Admitting a prior history with David Chang, Jonathan Gold gives a blow-by-blow account of his meals at Majordomo, the Momofuku founder’s first foray into Los Angeles.\n      \n\n \n3 MIN, 56 SEC\nApr 20, 2018\n \n\n\n        Jonathan Gold tries the exquisite sushi at Shiki Beverly Hills\n      \n\n\n\n        Chef Mori Onodera is serving up remarkable omakase to his loyal following of sushi aficionados.\n      \n\n \n3 MIN, 59 SEC\nApr 06, 2018\n \nLOAD MORE\n \n\n\n        Congratulations to the 2018 Good Food Pie Contest Winners!\n      \n\n\n\n        Curious which of the nearly 500 entered pies won this year’s Pie Contest? Check out the highlights! \n  Read More\n      \n\n \nMay 08, 2018\n \n\n\n        MAPPED: A pie crawl on the East Side\n      \n\n\n\n        KCRW pie contest judge Isa Fabro takes us to her favorite places to eat pie on LA’s East Side. \n  Read More\n      \n\n \nMay 04, 2018\n \n\n\n        Make Evan Kleiman’s apple pie recipe from The Simpsons\n      \n\n\n\n        Yes, it’s true! Our very own pie-queen Evan Kleiman’s apple pie recipe has been memorialized on one of America’s most popular, long-running television shows, The Simpsons. We asked Kleiman to spill the details (and the full recipe) on her relationship with the cartoon. \n  Read More ...
#   'Jonathan Gold dines at Ink.well in West Hollywood | Good Food on the Road | KCRW',
#   'Jonathan Gold heads to Michael Voltaggio’s Ink.well to find a slightly more accessible reboot of his shuttered restaurant Ink.']}

# %%
from tqdm import tqdm_notebook
import spacy
nlp = spacy.load('en')
article_docs = articles.collection.find({})#, projection=['content'])
article_docs = map(lambda x: x.get('content'), article_docs)
article_docs = filter(lambda x: x is not None and x != '', article_docs)
article_docs = list(article_docs)

words = set()
for name in tqdm_notebook(nlp.pipe(article_docs, disable=nlp.pipe_names), total=len(article_docs)):
    for word in name:
        words.add(word.text)
        
words = list(words)
# Out:
# HBox(children=(IntProgress(value=0, max=1039), HTML(value='')))

# %% [markdown]
# ### Make Labels + Noise

# %%
import numpy as np
import random
from spacy.gold import GoldParse

names = restaurants.collection.find({}, projection=['name'])
names = map(lambda x: x.get('name'), names)
names = list(names)
golds = []
docs=[]
for name in tqdm_notebook(names, total=len(names)):
    start_n, end_n = np.random.choice([1, 2, 3]), np.random.choice([1, 2, 3])
    
    start_string = " ".join(np.random.choice(words, size = start_n).tolist())
    end_string = " ".join(np.random.choice(words, size = end_n).tolist())
    new_name = start_string + " " + name +" "+ end_string
    
    doc = nlp(new_name, disable=nlp.pipe_names)
    inner_n = len(doc) - start_n - end_n
    #print(doc)
    entities = []
    N = len(doc)
    for i, word in enumerate(doc):
        # start n(2) -> 0, 1, not 2
        if i < start_n:
            ent = 'O'
        elif i < start_n + inner_n:
            if inner_n == 1:
                ent = 'U-RESTAURANT'
            else:
                if i == start_n:
                    ent = 'B-RESTAURANT'
                elif i < (inner_n + start_n - 1):
                    ent = 'I-RESTAURANT'
                else:
                    ent = 'L-RESTAURANT'
        else:
            ent = 'O'
        entities.append(ent)
        
    golds.append(GoldParse(doc, entities=entities))
    docs.append(doc)

# %%
review_iter = articles.collection.find({'is_review': True})

# %% [markdown]
# ### Train

# %%
import random
txt = 'Is Los Angeles a fried chicken town? The hours-long lines at Howlin’ Ray’s at the Far East Plaza in Chinatown seem to suggest so.'
n_iter = 1
nlp = spacy.load('en')
nlp.entity.add_label('RESTAURANT')

train_data =list(zip(docs, golds))
optimizer = nlp.begin_training()
try:
    for itn in tqdm_notebook(range(n_iter), total=n_iter):
        random.shuffle(train_data)
        for j, (doc, gold) in enumerate(tqdm_notebook(train_data, total=len(train_data))):
            nlp.update([doc], [gold], drop=0.5, sgd=optimizer)   
            if j % 20 == 0:
                for e in nlp(txt).ents:
                    print(e, e.label_)
                print()
except KeyboardInterrupt:
    pass
# Out:
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=13768), HTML(value='')))
# Los Angeles GPE
# hours TIME
# Ray PERSON
# the Far East Plaza FAC
#
# Los Angeles GPE
# hours TIME
# Ray PERSON
# the Far East Plaza LOC
#
# Los Angeles GPE
# hours TIME
# Ray PERSON
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray PERSON
# the Far East Plaza LOC
#
# the Far East Plaza LOC
#
# the Far East Plaza LOC
#
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray PERSON
# the Far East Plaza LOC
#
# the Far East Plaza LOC
#
# Los Angeles GPE
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s at RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s at RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s at RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s at RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s at RESTAURANT
# the Far East Plaza LOC
#
# Los Angeles GPE
# Ray’s RESTAURANT
#
# Los Angeles GPE
# Ray’s RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
#
# Ray’s at the Far East Plaza in Chinatown seem to suggest so. RESTAURANT
#
# Ray’s at the Far East Plaza in Chinatown seem to suggest so. RESTAURANT
#
# Ray’s at the Far East Plaza in Chinatown seem to suggest so. RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Los Angeles GPE
# Howlin’ Ray RESTAURANT
#
# Los Angeles GPE
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Los Angeles RESTAURANT
# Howlin’ Ray’s at the Far East Plaza RESTAURANT
#
# Howlin’ Ray’s at the Far East Plaza RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
# the Far East Plaza LOC
#
# Howlin’ Ray RESTAURANT
# the Far East Plaza LOC
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Ray’s RESTAURANT
#
#
# Howlin’ Ray RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Howlin’ Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Howlin’ Ray RESTAURANT
#
# Howlin’ Ray RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Howlin’ Ray’s RESTAURANT
#
# Howlin’ Ray’s RESTAURANT
#
# Howlin’ Ray’s RESTAURANT
#
# Howlin’ Ray’s RESTAURANT
#
# Howlin’ Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
# the Far East Plaza LOC
#
# Howlin’ Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Is Los Angeles RESTAURANT
# Howlin’ Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza in Chinatown RESTAURANT
#
# The hours-long RESTAURANT
# Ray’s at the Far East Plaza in Chinatown RESTAURANT
#
# Ray’s at the Far East Plaza RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles a fried chicken RESTAURANT
# Ray’s at the Far East Plaza in Chinatown seem to suggest so RESTAURANT
#
# Ray’s at the Far East Plaza in Chinatown seem to suggest so RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
# Far East Plaza RESTAURANT
#
# Los Angeles a fried RESTAURANT
# The hours-long RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles a fried chicken RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles a fried chicken RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles a fried chicken town? RESTAURANT
# Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles a fried chicken town? RESTAURANT
# The hours-long lines at Howlin’ Ray’s at the Far East Plaza in Chinatown RESTAURANT
#
# Los Angeles a fried chicken RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles a fried chicken RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
# Los Angeles a fried chicken RESTAURANT
# The hours-long lines at RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles a fried chicken RESTAURANT
# The hours-long lines at RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles a fried chicken town? RESTAURANT
# The hours-long lines at Howlin’ Ray’s at the Far East Plaza RESTAURANT
#
# Los Angeles a fried chicken town? RESTAURANT
# The hours-long lines at Howlin’ Ray’s at the Far East Plaza in Chinatown RESTAURANT
#
# The hours-long lines at Howlin’ Ray’s at the Far East Plaza in Chinatown RESTAURANT
#
# Los Angeles RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
#
# Los Angeles RESTAURANT
# The hours-long RESTAURANT
# Ray’s at RESTAURANT
